# %% [markdown]
# # Найти пару наборов данных и построить для них гистограмму распределения в Python.

# %%
import pandas as pd 
import numpy as np

# %%
RBS = pd.read_csv('/Users/egorgusev/Анализ данных/Задание 1/RBS.csv', sep=';', encoding='Windows-1251', decimal=',')

# %%
RBS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717755 entries, 0 to 717754
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ID_ROUTE         717755 non-null  int64
#  1   ID_ROUTE_ASUGPT  717755 non-null  int64
#  2   ID_TRANSPORT     717755 non-null  int64
#  3   ROUTE_NUMBER     717755 non-null  object
#  4   ROUTE_NAME       717755 non-null  object
#  5   STOP_NUMBER      717755 non-null  int64
#  6   DIRECTION        717755 non-null  int64
#  7   ID_STOP          717755 non-null  int64
#  8   ID_NEXT_STOP     717755 non-null  int64
#  9   DISTANCE         717755 non-null  float64
#  10  LATITUDE         717755 non-null  float64
#  11  LONGITUDE        717755 non-null  float64
#  12  CHECK_           717755 non-null  float64
#  13  DDATE            717755 non-null  object
#  14  ROUTE_VARIANT    717755 non-null  int64
# dtypes: float64(4), int64(8), object(3)
# memory usage: 82.1+ MB

# %%
RBS.head()
# Out:
#    ID_ROUTE  ID_ROUTE_ASUGPT  ID_TRANSPORT ROUTE_NUMBER  \
# 0      1036             1318             1          115
# 1      1036             1318             1          115
# 2     15006             1342             1         115А
# 3     15006             1342             1         115А
# 4       283             1314             1          116
#
#                                           ROUTE_NAME  STOP_NUMBER  DIRECTION  \
# 0  АВТОБУСНАЯ СТАНЦИЯ "ПР. АЛЕКСАНДРОВСКОЙ ФЕРМЫ"...            0          2
# 1  АВТОБУСНАЯ СТАНЦИЯ "ПР. АЛЕКСАНДРОВСКОЙ ФЕРМЫ"...            2          2
# 2  АВТОБУСНАЯ СТАНЦИЯ "ПР. АЛЕКСАНДРОВСКОЙ ФЕРМЫ"...           18          2
# 3  АВТОБУСНАЯ СТАНЦИЯ "ПР. АЛЕКСАНДРОВСКОЙ ФЕРМЫ"...            5          1
# 4                   ЗВЕЗДНАЯ УЛ. - Б. СМОЛЕНСКИЙ ПР.            4          2
#
#    ID_STOP  ID_NEXT_STOP  DISTANCE   LATITUDE  LONGITUDE  CHECK_  \
# 0    17071          1681      0.41  59.790199  30.568491    0.50
# ...

# %%
print(RBS.shape)
# Out:
# (717755, 15)

# %%
#RBS['ID_ROUTE'].unique()

# %%
RBS.describe(include = 'all')
# Out:
#             ID_ROUTE  ID_ROUTE_ASUGPT   ID_TRANSPORT ROUTE_NUMBER  \
# count   7.177550e+05    717755.000000  717755.000000       717755
# unique           NaN              NaN            NaN          654
# top              NaN              NaN            NaN           40
# freq             NaN              NaN            NaN         7050
# mean    1.489178e+04      1772.202949       1.262478          NaN
# std     1.100375e+05      1039.648503       0.618133          NaN
# min     1.100000e+01       221.000000       1.000000          NaN
# 25%     3.390000e+02      1125.000000       1.000000          NaN
# 50%     1.026000e+03      1670.000000       1.000000          NaN
# 75%     1.553700e+04      1904.000000       1.000000          NaN
# max     2.131358e+06      6687.000000       3.000000          NaN
#
#                                             ROUTE_NAME    STOP_NUMBER  \
# count                                           717755  717755.000000
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
RBS[RBS['DISTANCE'] == max(RBS['DISTANCE'])]
# Out:
#         ID_ROUTE  ID_ROUTE_ASUGPT  ID_TRANSPORT ROUTE_NUMBER  \
# 12813      16224             3035             1        К-469
# 30431      16224             3035             1        К-469
# 36933      16224             3035             1        К-469
# 86906      16224             3035             1        К-469
# 88612      16224             3035             1        К-469
# 101598     16224             3035             1        К-469
# 103791     16224             3035             1        К-469
# 105553     16224             3035             1        К-469
# 105875     16224             3035             1        К-469
# 140912     16224             3035             1        К-469
# 159399     16224             3035             1        К-469
# 176036     16224             3035             1        К-469
# 178765     16224             3035             1        К-469
# 198325     16224             3035             1        К-469
# ...

# %%
RBS['DISTANCE'].describe()
# Out:
# count    717755.000000
# mean          0.954361
# std           1.525203
# min           0.010000
# 25%           0.400000
# 50%           0.540000
# 75%           0.810000
# max          33.150000
# Name: DISTANCE, dtype: float64

# %%
RBS['DISTANCE'].hist(bins=80);

# %%
RBS[RBS['DISTANCE'] < 10]['DISTANCE'].hist(bins=80);

# %%
RBS[RBS['DISTANCE'] < 2]['DISTANCE'].hist(bins=200);

# %%
RBS[RBS['DISTANCE'] < 3]['DISTANCE'].hist(bins=80, normed=1);
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %%
RBS['DISTANCE'].hist(bins=200, normed=1);

# %%
np.log(RBS['DISTANCE']).hist(bins=80, normed=1);

# %%
from scipy.stats.kde import gaussian_kde
from numpy import linspace,hstack 
from pylab import plot,show,hist

# %%
RBS3 = RBS[RBS['DISTANCE'] < 3]

# %%
my_density = gaussian_kde(RBS3['DISTANCE'])

# %%
x = linspace(min(RBS3['DISTANCE']), max(RBS3['DISTANCE']), 50) 
plot(x, my_density(x),'g') 
#hist(RBS3['DISTANCE'], normed=1, alpha=.3) 
show()

# %%
ROUTE = pd.read_csv('/Users/egorgusev/Транспорт/Другие данные/ROUTEdata-20191014T093206-structure-20190416T084446.csv', sep=',', encoding='UTF-8')

# %%
ROUTE
# Out:
#        number  route_id route_short_name  \
# 0           1      1850              494
# 1           2      1850              494
# 2           3      1850              494
# 3           4      1850              494
# 4           5      1850              494
# ...       ...       ...              ...
# 21166   21167      1673               25
# 21167   21168      1673               25
# 21168   21169      1673               25
# 21169   21170      1673               25
# 21170   21171      1673               25
#
#                                          route_long_name transport_type  \
# 0      "ПОС. БЕЛООСТРОВ" - АЛЕКСАНДРОВСКОЕ ШОССЕ, САД...        Автобус
# 1      "ПОС. БЕЛООСТРОВ" - АЛЕКСАНДРОВСКОЕ ШОССЕ, САД...        Автобус
# 2      "ПОС. БЕЛООСТРОВ" - АЛЕКСАНДРОВСКОЕ ШОССЕ, САД...        Автобус
# 3      "ПОС. БЕЛООСТРОВ" - АЛЕКСАНДРОВСКОЕ ШОССЕ, САД...        Автобус
# 4      "ПОС. БЕЛООСТРОВ" - АЛЕКСАНДРОВСКОЕ ШОССЕ, САД...        Автобус
# ...

# %%
ROUTE.describe(include = 'all')
# Out:
#              number      route_id route_short_name  \
# count   21171.00000  21171.000000            21171
# unique          NaN           NaN              384
# top             NaN           NaN               40
# freq            NaN           NaN              235
# mean    10586.00000   1623.267536              NaN
# std      6111.68561    992.106442              NaN
# min         1.00000    221.000000              NaN
# 25%      5293.50000   1113.000000              NaN
# 50%     10586.00000   1548.000000              NaN
# 75%     15878.50000   1791.000000              NaN
# max     21171.00000   6626.000000              NaN
#
#                                        route_long_name transport_type  \
# count                                            21171          21171
# unique                                             457              3
# top     А.С. "ПР. КУЛЬТУРЫ" - А.С."ПР. МАРШАЛА ЖУКОВА"        Автобус
# ...

# %%
ROUTE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21171 entries, 0 to 21170
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   number            21171 non-null  int64
#  1   route_id          21171 non-null  int64
#  2   route_short_name  21171 non-null  object
#  3   route_long_name   21171 non-null  object
#  4   transport_type    21171 non-null  object
#  5   direction         21171 non-null  object
#  6   stop_id           21171 non-null  int64
#  7   next_stop         21171 non-null  int64
#  8   stop_distance     21171 non-null  float64
#  9   stop_name         21171 non-null  object
#  10  coordinates       21171 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.8+ MB

# %%
ROUTE['stop_distance'].hist(bins = 100);

# %%
ROUTE['stop_distance'].hist(bins = 100, density = 1);

# %%
stopdist3 = ROUTE[ROUTE['stop_distance'] < 3]['stop_distance']

# %%
stopdist3.hist(bins = 50, normed=1);
RBS[RBS['DISTANCE'] < 3]['DISTANCE'].hist(bins=50, normed=1);

# %%
hist(RBS3['DISTANCE'], bins = 100, density =1, alpha=.3) 
hist(stopdist3, bins = 30, density = 1, alpha = .3)
show()
